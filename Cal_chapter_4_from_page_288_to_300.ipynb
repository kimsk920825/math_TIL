# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import fsolve
import sympy
from scipy.misc import derivative
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import scipy as sp
import pandas as pd
import statsmodels.api as sm
import sklearn as sk

# %%
def f(x):
    return x**3-3*x**2+x
x = np.linspace(-1,3,400)
y = f(x)

plt.plot(x,y)
plt.plot(0,0,'ro')
plt.plot(x,x,'r:') #아직 해결 안됨
plt.plot(1,-1,'go')
plt.plot(x, (3*1**2-6*1+1)*(x-1)-1,'g--')

#전체 그래프 크기 조절
plt.xlim(-3.5, 5.5)
plt.ylim(-4,2)
plt.xticks(np.arange(-3,6))
plt.yticks(np.arange(-4,2))

plt.annotate('',xy=(1,0),xytext=(0,0),arrowprops=dict(facecolor='gray'))
plt.annotate('',xy=(1,1),xytext=(1,0),arrowprops=dict(facecolor='gray'))

plt.annotate('',xy=(2,-1), xytext=(1,-1), arrowprops=dict(facecolor='gray'))
plt.annotate('',xy=(2,-3),xytext=(2,-1),arrowprops=dict(facecolor='gray'))

plt.xlabel('x')
plt.ylabel('f(x)')

plt.title('slope of the function')

plt.show()

# %%
#위 그래프의 x값에 대한 기울깃값을 도함수의 그래프로 그려봐라. 
x = np.array([-.5,0,0.5,1,1.5,2,2.5])
y = np.array([2.5,1,-1,-2,-1,1,2.5])

plt.title('a graph of the derivative')
plt.plot(x,y,'b-')

# %%
#함수, 도함수, 2차도함수 
def fprime2(x):
    return 6*x-6
#2차 방정식의 근
x1, x2 = np.roots([3,-6,1])

x=np.linspace(-1,3,400)

plt.figure(figsize=(10,10))

plt.subplot(311)
plt.plot(x,f(x))
plt.xlim(-2,4)
plt.xticks(np.arange(-1,4))
plt.yticks(np.arange(-5,4))
plt.title('function f(x)')
plt.xlabel('x')
plt.axvline(x1,c='b',ls='--')
plt.axvline(x2,c='b',ls='--')
plt.axvline(1,c='g',ls=':')

plt.subplot(312)
plt.plot(x,fprime(x))
plt.xlim(-2,4)
plt.xticks(np.arange(-1,4))
plt.yticks(np.arange(-3,11))
plt.title("derivative f'(x)")
plt.xlabel('x')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d99c1b06364d> in <module>
#      21
#      22 plt.subplot(312)
# ---> 23 plt.plot(x,fprime(x))
#      24 plt.xlim(-2,4)
#      25 plt.xticks(np.arange(-1,4))
#
# NameError: name 'fprime' is not defined
